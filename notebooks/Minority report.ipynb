# %%
import pandas as pd
df = pd.read_csv('../raw_data/NYPD_Complaint_Data_Historic.csv')
df.head(10)
# Out:
# /Users/camillebenhaim/.pyenv/versions/3.8.5/envs/minority_report/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3146: DtypeWarning: Columns (18,20) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#    CMPLNT_NUM CMPLNT_FR_DT CMPLNT_FR_TM CMPLNT_TO_DT CMPLNT_TO_TM  \
# 0   325341655   02/11/2015     15:00:00          NaN          NaN
# 1   393816841   03/17/2012     10:30:00   03/17/2012     11:00:00
# 2   802896158   10/27/2016     13:48:00   11/03/2016     13:49:00
# 3   633812343   11/27/2014     19:00:00   11/27/2014     22:30:00
# 4   300349533   12/11/2013     13:30:00   12/11/2013     14:15:00
# 5   944253539   08/28/2013     11:00:00   08/28/2013     11:30:00
# 6   608679532   12/04/2013     18:30:00   12/04/2013     18:40:00
# 7   882178622   09/14/2013     08:40:00   09/14/2013     08:40:00
# 8   240183498   01/31/2013     23:47:00          NaN          NaN
# 9   895680254   09/17/2016     00:05:00   09/17/2016     00:15:00
#
#    ADDR_PCT_CD      RPT_DT  KY_CD                       OFNS_DESC  PD_CD  ...  \
# 0         73.0  02/11/2015    359  OFFENSES AGAINST PUBLIC ADMINI  749.0  ...
# 1         69.0  03/17/2012    344    ASSAULT 3 & RELATED OFFENSES  114.0  ...
# 2         71.0  11/03/2016    578                   HARRASSMENT 2  638.0  ...
# 3        112.0  11/28/2014    104                            RAPE  157.0  ...
# 4         24.0  12/12/2013    109                   GRAND LARCENY  438.0  ...
# 5         63.0  08/28/2013    341                   PETIT LARCENY  333.0  ...
# 6        101.0  12/05/2013    361   OFF. AGNST PUB ORD SENSBLTY &  639.0  ...
# 7         49.0  09/14/2013    578                   HARRASSMENT 2  638.0  ...
# 8         40.0  01/31/2013    352               CRIMINAL TRESPASS  205.0  ...
# 9         60.0  09/17/2016    351  CRIMINAL MISCHIEF & RELATED OF  259.0  ...
#
#   SUSP_SEX TRANSIT_DISTRICT   Latitude  Longitude  \
# 0        M              NaN  40.664239 -73.908425
# 1      NaN              NaN  40.644590 -73.892672
# 2        M              NaN  40.658758 -73.942435
# 3        M              NaN  40.722364 -73.851474
# 4      NaN              NaN  40.793465 -73.968950
# 5      NaN              NaN  40.625320 -73.917874
# 6        F              NaN  40.600172 -73.756663
# 7        M              NaN  40.851041 -73.861441
# 8      NaN              NaN  40.805504 -73.916477
# 9        M              NaN  40.572501 -73.999098
#
#                          Lat_Lon               PATROL_BORO STATION_NAME  \
# 0  (40.664239422, -73.908425011)   PATROL BORO BKLYN NORTH          NaN
# 1  (40.644589618, -73.892672426)   PATROL BORO BKLYN SOUTH          NaN
# 2  (40.658758183, -73.942434788)   PATROL BORO BKLYN SOUTH          NaN
# 3  (40.722363687, -73.851473894)  PATROL BORO QUEENS NORTH          NaN
# 4  (40.793464597, -73.968949638)     PATROL BORO MAN NORTH          NaN
# 5  (40.625319998, -73.917873518)   PATROL BORO BKLYN SOUTH          NaN
# 6  (40.600171728, -73.756663063)  PATROL BORO QUEENS SOUTH          NaN
# 7  (40.851041106, -73.861441322)         PATROL BORO BRONX          NaN
# 8  (40.805504347, -73.916477252)         PATROL BORO BRONX          NaN
# 9  (40.572500982, -73.999097946)   PATROL BORO BKLYN SOUTH          NaN
#
#    VIC_AGE_GROUP        VIC_RACE VIC_SEX
# 0            <18           BLACK       M
# 1          45-64           BLACK       F
# 2          18-24           BLACK       M
# 3          25-44           WHITE       F
# 4          45-64           WHITE       F
# 5            NaN         UNKNOWN       D
# 6          45-64           BLACK       F
# 7          25-44  WHITE HISPANIC       F
# 8            NaN         UNKNOWN       E
# 9          25-44           BLACK       F
#
# [10 rows x 35 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6983207 entries, 0 to 6983206
# Data columns (total 35 columns):
#  #   Column             Dtype
# ---  ------             -----
#  0   CMPLNT_NUM         int64
#  1   CMPLNT_FR_DT       object
#  2   CMPLNT_FR_TM       object
#  3   CMPLNT_TO_DT       object
#  4   CMPLNT_TO_TM       object
#  5   ADDR_PCT_CD        float64
#  6   RPT_DT             object
#  7   KY_CD              int64
#  8   OFNS_DESC          object
#  9   PD_CD              float64
#  10  PD_DESC            object
#  11  CRM_ATPT_CPTD_CD   object
#  12  LAW_CAT_CD         object
#  13  BORO_NM            object
#  14  LOC_OF_OCCUR_DESC  object
#  15  PREM_TYP_DESC      object
#  16  JURIS_DESC         object
#  17  JURISDICTION_CODE  float64
#  18  PARKS_NM           object
#  19  HADEVELOPT         object
#  20  HOUSING_PSA        object
#  21  X_COORD_CD         float64
#  22  Y_COORD_CD         float64
#  23  SUSP_AGE_GROUP     object
#  24  SUSP_RACE          object
#  25  SUSP_SEX           object
#  26  TRANSIT_DISTRICT   float64
#  27  Latitude           float64
#  28  Longitude          float64
#  29  Lat_Lon            object
#  30  PATROL_BORO        object
#  31  STATION_NAME       object
#  32  VIC_AGE_GROUP      object
#  33  VIC_RACE           object
#  34  VIC_SEX            object
# dtypes: float64(8), int64(2), object(25)
# memory usage: 1.8+ GB

# %%
df.isna().sum()
# Out:
# CMPLNT_NUM                 0
# CMPLNT_FR_DT             655
# CMPLNT_FR_TM              48
# CMPLNT_TO_DT         1668376
# CMPLNT_TO_TM         1663829
# ADDR_PCT_CD             2166
# RPT_DT                     0
# KY_CD                      0
# OFNS_DESC              18825
# PD_CD                   5865
# PD_DESC                 5865
# CRM_ATPT_CPTD_CD           7
# LAW_CAT_CD                 0
# BORO_NM                10894
# LOC_OF_OCCUR_DESC    1479992
# PREM_TYP_DESC          39732
# JURIS_DESC                 0
# JURISDICTION_CODE       5865
# PARKS_NM             6958159
# HADEVELOPT           6637179
# HOUSING_PSA          6446298
# X_COORD_CD             24064
# Y_COORD_CD             24064
# SUSP_AGE_GROUP       4707573
# SUSP_RACE            3339032
# SUSP_SEX             3472346
# TRANSIT_DISTRICT     6826123
# Latitude               24064
# Longitude              24064
# Lat_Lon                24064
# PATROL_BORO             6322
# STATION_NAME         6826123
# VIC_AGE_GROUP        1638444
# VIC_RACE                 308
# VIC_SEX                  307
# dtype: int64

# %%
df['CMPLNT_FR_DT'].value_counts()
# Out:
# 01/01/2010    2494
# 01/01/2016    2394
# 01/01/2014    2386
# 01/01/2011    2379
# 01/01/2008    2354
#               ...
# 12/23/1967       1
# 07/07/2001       1
# 03/19/2003       1
# 08/13/2003       1
# 10/29/2001       1
# Name: CMPLNT_FR_DT, Length: 8178, dtype: int64

# %%
df['CMPLNT_FR_DT'].sort_values()[:-655]
# Out:
# 1558047    01/01/1948
# 6045835    01/01/1964
# 2328772    01/01/1965
# 2317128    01/01/1965
# 1849111    01/01/1965
#               ...
# 2293343    12/31/2019
# 2293331    12/31/2019
# 2293321    12/31/2019
# 2293266    12/31/2019
# 2292099    12/31/2019
# Name: CMPLNT_FR_DT, Length: 6982552, dtype: object

# %%
df['BORO_NM'].unique()
# Out:
# array(['BROOKLYN', 'QUEENS', 'MANHATTAN', 'BRONX', 'STATEN ISLAND', nan],
#       dtype=object)

# %%
df['CRM_ATPT_CPTD_CD'].value_counts()
# Out:
# COMPLETED    6863758
# ATTEMPTED     119442
# Name: CRM_ATPT_CPTD_CD, dtype: int64

# %%
df['LAW_CAT_CD'].value_counts()
# Out:
# MISDEMEANOR    3938246
# FELONY         2150008
# VIOLATION       894953
# Name: LAW_CAT_CD, dtype: int64

# %%
df['VIC_SEX'].value_counts()
# Out:
# F    2733665
# M    2288821
# E    1119264
# D     841146
# U          4
# Name: VIC_SEX, dtype: int64

# %%
df[df['LAW_CAT_CD']=='VIOLATION']
# Out:
#          CMPLNT_NUM CMPLNT_FR_DT CMPLNT_FR_TM CMPLNT_TO_DT CMPLNT_TO_TM  \
# 2         802896158   10/27/2016     13:48:00   11/03/2016     13:49:00
# 7         882178622   09/14/2013     08:40:00   09/14/2013     08:40:00
# 14        882568598   06/28/2017     09:30:00   06/28/2017     09:45:00
# 21        171315231   06/21/2015     11:25:00          NaN          NaN
# 24        639884813   08/26/2015     18:15:00   08/26/2015     18:30:00
# ...             ...          ...          ...          ...          ...
# 6983157   488162445   05/19/2018     17:30:00   05/19/2018     17:35:00
# 6983163   852126788   10/13/2018     09:00:00   10/13/2018     09:10:00
# 6983173   281088297   10/03/2018     16:30:00   10/03/2018     16:45:00
# 6983190   902959278   03/01/2018     00:01:00   03/27/2019     10:00:00
# 6983195   539235652   11/27/2018     21:45:00   11/27/2018     21:46:00
#
#          ADDR_PCT_CD      RPT_DT  KY_CD      OFNS_DESC  PD_CD  ... SUSP_SEX  \
# 2               71.0  11/03/2016    578  HARRASSMENT 2  638.0  ...        M
# 7               49.0  09/14/2013    578  HARRASSMENT 2  638.0  ...        M
# 14             120.0  06/28/2017    578  HARRASSMENT 2  638.0  ...        U
# 21              88.0  06/21/2015    578  HARRASSMENT 2  638.0  ...        M
# 24              30.0  08/26/2015    578  HARRASSMENT 2  638.0  ...        M
# ...              ...         ...    ...            ...    ...  ...      ...
# 6983157         25.0  05/23/2018    578  HARRASSMENT 2  638.0  ...        F
# 6983163        109.0  10/13/2018    578  HARRASSMENT 2  637.0  ...        M
# 6983173         79.0  10/03/2018    578  HARRASSMENT 2  638.0  ...        F
# 6983190         88.0  04/30/2019    578  HARRASSMENT 2  638.0  ...        M
# 6983195         28.0  11/27/2018    578  HARRASSMENT 2  638.0  ...        M
#
#         TRANSIT_DISTRICT   Latitude  Longitude                        Lat_Lon  \
# 2                    NaN  40.658758 -73.942435  (40.658758183, -73.942434788)
# 7                    NaN  40.851041 -73.861441  (40.851041106, -73.861441322)
# 14                   NaN  40.647128 -74.088181  (40.647128347, -74.088181423)
# 21                   NaN  40.688488 -73.976848   (40.688487945, -73.97684841)
# 24                   NaN  40.822381 -73.953544  (40.822380578, -73.953544401)
# ...                  ...        ...        ...                            ...
# 6983157              NaN  40.811130 -73.936715  (40.811130194, -73.936714506)
# 6983163              NaN  40.756473 -73.815743  (40.756473314, -73.815743032)
# 6983173              NaN  40.680891 -73.944867   (40.680890516, -73.94486737)
# 6983190              NaN        NaN        NaN                            NaN
# 6983195              NaN  40.801714 -73.950001   (40.80171408, -73.950001039)
#
#                        PATROL_BORO STATION_NAME  VIC_AGE_GROUP  \
# 2          PATROL BORO BKLYN SOUTH          NaN          18-24
# 7                PATROL BORO BRONX          NaN          25-44
# 14       PATROL BORO STATEN ISLAND          NaN          45-64
# 21         PATROL BORO BKLYN NORTH          NaN          45-64
# 24           PATROL BORO MAN NORTH          NaN          45-64
# ...                            ...          ...            ...
# 6983157      PATROL BORO MAN NORTH          NaN          25-44
# 6983163   PATROL BORO QUEENS NORTH          NaN          25-44
# 6983173    PATROL BORO BKLYN NORTH          NaN            <18
# 6983190    PATROL BORO BKLYN NORTH          NaN          25-44
# 6983195      PATROL BORO MAN NORTH          NaN          45-64
#
#                          VIC_RACE VIC_SEX
# 2                           BLACK       M
# 7                  WHITE HISPANIC       F
# 14                          BLACK       F
# 21                          BLACK       F
# 24                 WHITE HISPANIC       F
# ...                           ...     ...
# 6983157            WHITE HISPANIC       F
# 6983163            WHITE HISPANIC       F
# 6983173                     BLACK       F
# 6983190                     BLACK       M
# 6983195  ASIAN / PACIFIC ISLANDER       M
#
# [894953 rows x 35 columns]

# %%
df['PREM_TYP_DESC'].unique()
# Out:
# array(['RESIDENCE - PUBLIC HOUSING', 'RESIDENCE-HOUSE', 'PUBLIC SCHOOL',
#        'RESIDENCE - APT. HOUSE', 'DOCTOR/DENTIST OFFICE',
#        'DEPARTMENT STORE', 'STREET', 'DRUG STORE', 'CHAIN STORE',
#        'RESTAURANT/DINER', 'HOSPITAL', 'TRANSIT - NYC SUBWAY',
#        'FOOD SUPERMARKET', 'BUS (NYC TRANSIT)', 'COMMERCIAL BUILDING',
#        'GAS STATION', 'FACTORY/WAREHOUSE', 'CLOTHING/BOUTIQUE',
#        'PRIVATE/PAROCHIAL SCHOOL', 'TELECOMM. STORE', 'GROCERY/BODEGA',
#        'BEAUTY & NAIL SALON', 'OTHER', 'PUBLIC BUILDING',
#        'SOCIAL CLUB/POLICY', 'TAXI (LIVERY LICENSED)',
#        'PARKING LOT/GARAGE (PUBLIC)', 'FAST FOOD', 'BAR/NIGHT CLUB',
#        'PARKING LOT/GARAGE (PRIVATE)', nan, 'PARK/PLAYGROUND', 'BANK',
#        'HOTEL/MOTEL', 'BUS TERMINAL', 'VARIETY STORE', 'SMALL MERCHANT',
#        'HIGHWAY/PARKWAY', 'CHURCH', 'STORE UNCLASSIFIED',
#        'DRY CLEANER/LAUNDRY', 'TUNNEL', 'MARINA/PIER', 'AIRPORT TERMINAL',
#        'CANDY STORE', 'ATM', 'GYM/FITNESS FACILITY',
#        'TAXI (YELLOW LICENSED)', 'JEWELRY', 'SYNAGOGUE',
#        'OPEN AREAS (OPEN LOTS)', 'LIQUOR STORE', 'PHOTO/COPY',
#        'BOOK/CARD', 'STORAGE FACILITY', 'VIDEO STORE',
#        'FERRY/FERRY TERMINAL', 'SHOE', 'LOAN COMPANY', 'BUS (OTHER)',
#        'CHECK CASHING BUSINESS', 'TRANSIT FACILITY (OTHER)',
#        'MAILBOX OUTSIDE', 'MOSQUE', 'BUS STOP', 'CONSTRUCTION SITE',
#        'BRIDGE', 'ABANDONED BUILDING', 'TAXI/LIVERY (UNLICENSED)',
#        'OTHER HOUSE OF WORSHIP', 'CEMETERY', 'TRAMWAY',
#        'HOMELESS SHELTER', 'MAILBOX INSIDE', 'DAYCARE FACILITY'],
#       dtype=object)

# %%
len(df['KY_CD'].unique())
# Out:
# 74

# %%
df['KY_CD'].value_counts()
# Out:
# 341    1165369
# 578     880714
# 344     731373
# 109     607713
# 351     584530
#         ...
# 881         15
# 357         11
# 123          7
# 362          4
# 577          3
# Name: KY_CD, Length: 74, dtype: int64

# %%
df['PD_DESC'].value_counts()
# Out:
# ASSAULT 3                         607342
# HARASSMENT,SUBD 3,4,5             567079
# AGGRAVATED HARASSMENT 2           361488
# LARCENY,PETIT FROM STORE-SHOPL    336337
# HARASSMENT,SUBD 1,CIVILIAN        313573
#                                    ...
# ABORTION 2, 1, SELF                    1
# ENVIRONMENTAL CONTROL BOARD            1
# ANARCHY,CRIMINAL                       1
# INCEST 3                               1
# PUBLIC HEALTH LAW,GLUE,INHALAT         1
# Name: PD_DESC, Length: 421, dtype: int64

# %%
df['OFNS_DESC'].value_counts()
# Out:
# PETIT LARCENY                      1165360
# HARRASSMENT 2                       880644
# ASSAULT 3 & RELATED OFFENSES        731300
# CRIMINAL MISCHIEF & RELATED OF      699377
# GRAND LARCENY                       607704
#                                     ...
# FELONY SEX CRIMES                       10
# ABORTION                                 7
# OFFENSES AGAINST MARRIAGE UNCL           4
# KIDNAPPING AND RELATED OFFENSES          3
# UNDER THE INFLUENCE OF DRUGS             3
# Name: OFNS_DESC, Length: 71, dtype: int64

# %%
df['JURIS_DESC'].value_counts()
# Out:
# N.Y. POLICE DEPT                       6203234
# N.Y. HOUSING POLICE                     532684
# N.Y. TRANSIT POLICE                     157405
# PORT AUTHORITY                           33254
# OTHER                                    22706
# DEPT OF CORRECTIONS                       9583
# POLICE DEPT NYC                           8955
# TRI-BORO BRDG TUNNL                       5590
# HEALTH & HOSP CORP                        3555
# N.Y. STATE POLICE                         1805
# NYC PARKS                                  877
# METRO NORTH                                800
# LONG ISLAND RAILRD                         544
# FIRE DEPT (FIRE MARSHAL)                   477
# N.Y. STATE PARKS                           441
# STATN IS RAPID TRANS                       426
# U.S. PARK POLICE                           266
# NEW YORK CITY SHERIFF OFFICE               258
# AMTRACK                                    184
# NYS DEPT TAX AND FINANCE                   101
# SEA GATE POLICE DEPT                        30
# CONRAIL                                     16
# NYC DEPT ENVIRONMENTAL PROTECTION           14
# DISTRICT ATTORNEY OFFICE                     1
# NYS DEPT ENVIRONMENTAL CONSERVATION          1
# Name: JURIS_DESC, dtype: int64

# %%
df['OFNS_DESC'].unique()
# Out:
# array(['OFFENSES AGAINST PUBLIC ADMINI', 'ASSAULT 3 & RELATED OFFENSES',
#        'HARRASSMENT 2', 'RAPE', 'GRAND LARCENY', 'PETIT LARCENY',
#        'OFF. AGNST PUB ORD SENSBLTY &', 'CRIMINAL TRESPASS',
#        'CRIMINAL MISCHIEF & RELATED OF', 'FELONY ASSAULT', 'SEX CRIMES',
#        'DANGEROUS DRUGS', 'BURGLARY', 'DANGEROUS WEAPONS', 'THEFT-FRAUD',
#        'ROBBERY', 'MISCELLANEOUS PENAL LAW',
#        'GRAND LARCENY OF MOTOR VEHICLE', 'INTOXICATED & IMPAIRED DRIVING',
#        'OTHER OFFENSES RELATED TO THEF', 'POSSESSION OF STOLEN PROPERTY',
#        'VEHICLE AND TRAFFIC LAWS', 'MURDER & NON-NEGL. MANSLAUGHTER',
#        'UNAUTHORIZED USE OF A VEHICLE', 'THEFT OF SERVICES',
#        'NYS LAWS-UNCLASSIFIED FELONY', 'OFFENSES INVOLVING FRAUD',
#        'FORGERY', 'ADMINISTRATIVE CODE', 'GAMBLING', 'FRAUDS', 'ARSON',
#        'OFFENSES AGAINST THE PERSON', nan, 'OFFENSES RELATED TO CHILDREN',
#        'PETIT LARCENY OF MOTOR VEHICLE', 'DISORDERLY CONDUCT',
#        'FRAUDULENT ACCOSTING', 'OTHER STATE LAWS (NON PENAL LA',
#        "BURGLAR'S TOOLS", 'CHILD ABANDONMENT/NON SUPPORT',
#        'ALCOHOLIC BEVERAGE CONTROL LAW', 'KIDNAPPING & RELATED OFFENSES',
#        'PROSTITUTION & RELATED OFFENSES', 'OTHER STATE LAWS', 'JOSTLING',
#        'NEW YORK CITY HEALTH CODE', 'OFFENSES AGAINST PUBLIC SAFETY',
#        'AGRICULTURE & MRKTS LAW-UNCLASSIFIED',
#        'LOITERING/GAMBLING (CARDS, DIC', 'LOITERING/DEVIATE SEX',
#        'HOMICIDE-NEGLIGENT,UNCLASSIFIE', 'ENDAN WELFARE INCOMP',
#        'LOITERING', 'ESCAPE 3', 'ANTICIPATORY OFFENSES',
#        'DISRUPTION OF A RELIGIOUS SERV', 'LOITERING FOR DRUG PURPOSES',
#        'OTHER TRAFFIC INFRACTION', 'INTOXICATED/IMPAIRED DRIVING',
#        'HOMICIDE-NEGLIGENT-VEHICLE', 'UNLAWFUL POSS. WEAP. ON SCHOOL',
#        'ADMINISTRATIVE CODES', 'UNDER THE INFLUENCE OF DRUGS',
#        'FORTUNE TELLING', 'ABORTION', 'KIDNAPPING',
#        'OTHER STATE LAWS (NON PENAL LAW)',
#        'NYS LAWS-UNCLASSIFIED VIOLATION',
#        'KIDNAPPING AND RELATED OFFENSES', 'FELONY SEX CRIMES',
#        'OFFENSES AGAINST MARRIAGE UNCL'], dtype=object)

# %%
df[df['JURIS_DESC']=='N.Y. HOUSING POLICE']['OFNS_DESC']
# Out:
# 0          OFFENSES AGAINST PUBLIC ADMINI
# 8                       CRIMINAL TRESPASS
# 14                          HARRASSMENT 2
# 36                         FELONY ASSAULT
# 51                          PETIT LARCENY
#                         ...
# 6983142                    FELONY ASSAULT
# 6983155    CRIMINAL MISCHIEF & RELATED OF
# 6983157                     HARRASSMENT 2
# 6983181                     PETIT LARCENY
# 6983184                        SEX CRIMES
# Name: OFNS_DESC, Length: 532684, dtype: object

# %%
df['LOC_OF_OCCUR_DESC'].unique()
# Out:
# array(['INSIDE', 'FRONT OF', nan, 'REAR OF', 'OPPOSITE OF', 'OUTSIDE'],
#       dtype=object)

# %%
# Out:
# PETIT LARCENY                      1165360
# HARRASSMENT 2                       880644
# ASSAULT 3 & RELATED OFFENSES        731300
# CRIMINAL MISCHIEF & RELATED OF      699377
# GRAND LARCENY                       607704
#                                     ...
# FELONY SEX CRIMES                       10
# ABORTION                                 7
# OFFENSES AGAINST MARRIAGE UNCL           4
# KIDNAPPING AND RELATED OFFENSES          3
# UNDER THE INFLUENCE OF DRUGS             3
# Name: OFNS_DESC, Length: 71, dtype: int64

# %%
df['STATION_NAME'].value_counts()
# Out:
# 125 STREET                        7987
# 14 STREET                         4391
# 34 ST.-PENN STATION               3717
# 42 ST.-PORT AUTHORITY BUS TERM    3621
# 116 STREET                        3383
#                                   ...
# DISTRICT 30 OFFICE                  16
# WEST 34 STREET/HUDSON YARDS         14
# DISTRICT 34 OFFICE                  13
# DISTRICT 23 OFFICE                   6
# OFF-SYSTEM                           4
# Name: STATION_NAME, Length: 372, dtype: int64

# %%
df['X_COORD_CD'].value_counts()
# Out:
# 987220.0     22144
# 1046367.0    15805
# 1016268.0     9327
# 981309.0      7286
# 1019840.0     7215
#              ...
# 975718.0         1
# 975863.0         1
# 975878.0         1
# 975924.0         1
# 134239.0         1
# Name: X_COORD_CD, Length: 71088, dtype: int64

# %%
df[['X_COORD_CD', 'Y_COORD_CD', 'Latitude', 'Longitude']]
# Out:
#          X_COORD_CD  Y_COORD_CD   Latitude  Longitude
# 0         1009656.0    181287.0  40.664239 -73.908425
# 1         1014035.0    174133.0  40.644590 -73.892672
# 2         1000222.0    179282.0  40.658758 -73.942435
# 3         1025420.0    202485.0  40.722364 -73.851474
# 4          992848.0    228356.0  40.793465 -73.968950
# ...             ...         ...        ...        ...
# 6983202   1023892.0    225321.0  40.785050 -73.856852
# 6983203         NaN         NaN        NaN        NaN
# 6983204   1010924.0    236074.0  40.814612 -73.903637
# 6983205         NaN         NaN        NaN        NaN
# 6983206         NaN         NaN        NaN        NaN
#
# [6983207 rows x 4 columns]

# %%
data = df.drop(columns=['CMPLNT_TO_DT',\
                      'CMPLNT_TO_TM', \
                      'HADEVELOPT',\
                      'HOUSING_PSA',\
                     'JURISDICTION_CODE',\
                      'KY_CD',\
                      'PD_CD',\
                      'PD_DESC',\
                      'RPT_DT',\
                      'TRANSIT_DISTRICT',\
                      'X_COORD_CD',\
                      'Y_COORD_CD',\
                        'Latitude',\
                        'Longitude'
                     ])

# %%
data.columns
# Out:
# Index(['CMPLNT_NUM', 'CMPLNT_FR_DT', 'CMPLNT_FR_TM', 'ADDR_PCT_CD',
#        'OFNS_DESC', 'CRM_ATPT_CPTD_CD', 'LAW_CAT_CD', 'BORO_NM',
#        'LOC_OF_OCCUR_DESC', 'PREM_TYP_DESC', 'JURIS_DESC', 'PARKS_NM',
#        'SUSP_AGE_GROUP', 'SUSP_RACE', 'SUSP_SEX', 'Lat_Lon', 'PATROL_BORO',
#        'STATION_NAME', 'VIC_AGE_GROUP', 'VIC_RACE', 'VIC_SEX'],
#       dtype='object')

# %%
# Rename columns for coherence
columns_dic={"CMPLNT_NUM":'complaint_id',\
        'CMPLNT_FR_DT':'date',\
        'CMPLNT_FR_TM':'time',\

         'LAW_CAT_CD':'offense_level',\
         'OFNS_DESC':'offense_type',\
         'CRM_ATPT_CPTD_CD':'crime_completed',\

         'LOC_OF_OCCUR_DESC':'premise_desc',\
         'PREM_TYP_DESC':'premise',\
         'Lat_Lon':'coordinates',\
          'BORO_NM':'borough',\
          'PATROL_BORO':'patrol_borough',\
         'ADDR_PCT_CD':'precinct_number',\
         'JURIS_DESC':'jurisdiction',\

         'SUSP_AGE_GROUP':'suspect_age',\
         'SUSP_RACE':'suspect_race',\
         'SUSP_SEX':'suspect_sex',\
         'VIC_AGE_GROUP':'victim_age',\
         'VIC_RACE':'victim_race',\
         'VIC_SEX':'victim_sex',\
         'PARKS_NM':'park_name',\
         'STATION_NAME':'metro',\
                    }

# %%
data.rename(columns_dic, inplace=True)

# %%
list_column = list(columns_dic.values())
list_column
# Out:
# ['complaint_id',
#  'date',
#  'time',
#  'offense_level',
#  'offense_type',
#  'crime_completed',
#  'premise_desc',
#  'premise',
#  'coordinates',
#  'borough',
#  'patrol_borough',
#  'precinct_number',
#  'jurisdiction',
#  'suspect_age',
#  'suspect_race',
#  'suspect_sex',
#  'victim_age',
#  'victim_race',
#  'victim_sex',
#  'park_name',
#  'metro']

# %%
# order columns for more comprehension
data.reindex(columns = list_column, copy=False)
# Out:
#          complaint_id        date      time offense_level  \
# 0           325341655  02/11/2015  15:00:00   MISDEMEANOR
# 1           393816841  03/17/2012  10:30:00   MISDEMEANOR
# 2           802896158  10/27/2016  13:48:00     VIOLATION
# 3           633812343  11/27/2014  19:00:00        FELONY
# 4           300349533  12/11/2013  13:30:00        FELONY
# ...               ...         ...       ...           ...
# 6983202     225471008  12/02/2018  04:15:00   MISDEMEANOR
# 6983203     368441925  01/20/2018  00:08:00   MISDEMEANOR
# 6983204     146134182  08/03/2018  22:30:00        FELONY
# 6983205     763119484  12/10/2018  11:00:00   MISDEMEANOR
# 6983206     176655779  11/15/2018  10:00:00        FELONY
#
#                            offense_type crime_completed premise_desc  \
# 0        OFFENSES AGAINST PUBLIC ADMINI       COMPLETED       INSIDE
# 1          ASSAULT 3 & RELATED OFFENSES       COMPLETED       INSIDE
# 2                         HARRASSMENT 2       COMPLETED       INSIDE
# 3                                  RAPE       COMPLETED       INSIDE
# 4                         GRAND LARCENY       COMPLETED       INSIDE
# ...                                 ...             ...          ...
# 6983202    ASSAULT 3 & RELATED OFFENSES       COMPLETED       INSIDE
# 6983203   OFF. AGNST PUB ORD SENSBLTY &       COMPLETED       INSIDE
# 6983204  CRIMINAL MISCHIEF & RELATED OF       COMPLETED     FRONT OF
# 6983205                          FRAUDS       COMPLETED       INSIDE
# 6983206  GRAND LARCENY OF MOTOR VEHICLE       COMPLETED       INSIDE
#
#                             premise                    coordinates    borough  \
# 0        RESIDENCE - PUBLIC HOUSING  (40.664239422, -73.908425011)   BROOKLYN
# 1                   RESIDENCE-HOUSE  (40.644589618, -73.892672426)   BROOKLYN
# 2                     PUBLIC SCHOOL  (40.658758183, -73.942434788)   BROOKLYN
# 3            RESIDENCE - APT. HOUSE  (40.722363687, -73.851473894)     QUEENS
# 4             DOCTOR/DENTIST OFFICE  (40.793464597, -73.968949638)  MANHATTAN
# ...                             ...                            ...        ...
# 6983202      RESIDENCE - APT. HOUSE  (40.785049616, -73.856851768)     QUEENS
# 6983203      RESIDENCE - APT. HOUSE                            NaN  MANHATTAN
# 6983204                      STREET  (40.814612305, -73.903637247)      BRONX
# 6983205      RESIDENCE - APT. HOUSE                            NaN     QUEENS
# 6983206          STORE UNCLASSIFIED                            NaN   BROOKLYN
#
#          ... precinct_number         jurisdiction suspect_age    suspect_race  \
# 0        ...            73.0  N.Y. HOUSING POLICE       25-44           BLACK
# 1        ...            69.0     N.Y. POLICE DEPT         NaN             NaN
# 2        ...            71.0     N.Y. POLICE DEPT         <18           BLACK
# 3        ...           112.0     N.Y. POLICE DEPT       25-44  WHITE HISPANIC
# 4        ...            24.0     N.Y. POLICE DEPT         NaN             NaN
# ...      ...             ...                  ...         ...             ...
# 6983202  ...           109.0     N.Y. POLICE DEPT       25-44  WHITE HISPANIC
# 6983203  ...            25.0     N.Y. POLICE DEPT       25-44           BLACK
# 6983204  ...            41.0     N.Y. POLICE DEPT         NaN             NaN
# 6983205  ...           107.0     N.Y. POLICE DEPT     UNKNOWN         UNKNOWN
# 6983206  ...            67.0     N.Y. POLICE DEPT         NaN             NaN
#
#         suspect_sex victim_age               victim_race victim_sex park_name  \
# 0                 M        <18                     BLACK          M       NaN
# 1               NaN      45-64                     BLACK          F       NaN
# 2                 M      18-24                     BLACK          M       NaN
# 3                 M      25-44                     WHITE          F       NaN
# 4               NaN      45-64                     WHITE          F       NaN
# ...             ...        ...                       ...        ...       ...
# 6983202           M      25-44  ASIAN / PACIFIC ISLANDER          F       NaN
# 6983203           F      25-44                     BLACK          M       NaN
# 6983204         NaN      25-44            BLACK HISPANIC          F       NaN
# 6983205           U      18-24  ASIAN / PACIFIC ISLANDER          M       NaN
# 6983206         NaN    UNKNOWN                   UNKNOWN          D       NaN
#
#         metro
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN
# ...       ...
# 6983202   NaN
# 6983203   NaN
# 6983204   NaN
# 6983205   NaN
# 6983206   NaN
#
# [6983207 rows x 21 columns]

# %%
data.head()
# Out:
#    complaint_id        date      time  precinct_number  \
# 0     325341655  02/11/2015  15:00:00             73.0
# 1     393816841  03/17/2012  10:30:00             69.0
# 2     802896158  10/27/2016  13:48:00             71.0
# 3     633812343  11/27/2014  19:00:00            112.0
# 4     300349533  12/11/2013  13:30:00             24.0
#
#                      offense_type crime_completed offense_level    borough  \
# 0  OFFENSES AGAINST PUBLIC ADMINI       COMPLETED   MISDEMEANOR   BROOKLYN
# 1    ASSAULT 3 & RELATED OFFENSES       COMPLETED   MISDEMEANOR   BROOKLYN
# 2                   HARRASSMENT 2       COMPLETED     VIOLATION   BROOKLYN
# 3                            RAPE       COMPLETED        FELONY     QUEENS
# 4                   GRAND LARCENY       COMPLETED        FELONY  MANHATTAN
#
#   premise_desc                     premise  ... park_name suspect_age  \
# 0       INSIDE  RESIDENCE - PUBLIC HOUSING  ...       NaN       25-44
# 1       INSIDE             RESIDENCE-HOUSE  ...       NaN         NaN
# 2       INSIDE               PUBLIC SCHOOL  ...       NaN         <18
# 3       INSIDE      RESIDENCE - APT. HOUSE  ...       NaN       25-44
# 4       INSIDE       DOCTOR/DENTIST OFFICE  ...       NaN         NaN
#
#      suspect_race suspect_sex                    coordinates  \
# 0           BLACK           M  (40.664239422, -73.908425011)
# 1             NaN         NaN  (40.644589618, -73.892672426)
# 2           BLACK           M  (40.658758183, -73.942434788)
# 3  WHITE HISPANIC           M  (40.722363687, -73.851473894)
# 4             NaN         NaN  (40.793464597, -73.968949638)
#
#              patrol_borough metro victim_age victim_race victim_sex
# 0   PATROL BORO BKLYN NORTH   NaN        <18       BLACK          M
# 1   PATROL BORO BKLYN SOUTH   NaN      45-64       BLACK          F
# 2   PATROL BORO BKLYN SOUTH   NaN      18-24       BLACK          M
# 3  PATROL BORO QUEENS NORTH   NaN      25-44       WHITE          F
# 4     PATROL BORO MAN NORTH   NaN      45-64       WHITE          F
#
# [5 rows x 21 columns]

# %%
data.columns
# Out:
# Index(['complaint_id', 'date', 'time', 'precinct_number', 'offense_type',
#        'crime_completed', 'offense_level', 'borough', 'premise_desc',
#        'premise', 'jurisdiction', 'park_name', 'suspect_age', 'suspect_race',
#        'suspect_sex', 'coordinates', 'patrol_borough', 'metro', 'victim_age',
#        'victim_race', 'victim_sex'],
#       dtype='object')

# %%
# full sur slack
data.to_csv('data.csv', index=False)

# %%
# sample [six derniers mois] pour github
data.sort_values('date')
# Out:
#          complaint_id        date      time  precinct_number  \
# 1558047     688541128  01/01/1948  04:00:00            105.0
# 6045835     135769527  01/01/1964  00:01:00             70.0
# 2328772     291498531  01/01/1965  00:00:00              5.0
# 2317128     291498531  01/01/1965  00:00:00              5.0
# 1849111     291498531  01/01/1965  00:00:00              5.0
# ...               ...         ...       ...              ...
# 6366470     619449411         NaN  11:30:00            107.0
# 6367153     457952823         NaN  03:00:00             62.0
# 6377708     776966472         NaN  07:45:00             73.0
# 6424655     959125529         NaN  06:00:00             90.0
# 6515212     912522930         NaN  10:00:00             79.0
#
#                           offense_type crime_completed offense_level  \
# 1558047  OFF. AGNST PUB ORD SENSBLTY &       COMPLETED   MISDEMEANOR
# 6045835                  GRAND LARCENY       COMPLETED        FELONY
# 2328772                     SEX CRIMES       COMPLETED        FELONY
# 2317128                     SEX CRIMES       COMPLETED        FELONY
# 1849111                     SEX CRIMES       COMPLETED        FELONY
# ...                                ...             ...           ...
# 6366470                  PETIT LARCENY       ATTEMPTED   MISDEMEANOR
# 6367153                  PETIT LARCENY       COMPLETED   MISDEMEANOR
# 6377708       VEHICLE AND TRAFFIC LAWS       COMPLETED   MISDEMEANOR
# 6424655                           RAPE       ATTEMPTED        FELONY
# 6515212                       BURGLARY       COMPLETED        FELONY
#
#            borough premise_desc                 premise  ... park_name  \
# 1558047     QUEENS       INSIDE         RESIDENCE-HOUSE  ...       NaN
# 6045835   BROOKLYN       INSIDE         RESIDENCE-HOUSE  ...       NaN
# 2328772  MANHATTAN       INSIDE  RESIDENCE - APT. HOUSE  ...       NaN
# 2317128  MANHATTAN       INSIDE  RESIDENCE - APT. HOUSE  ...       NaN
# 1849111  MANHATTAN       INSIDE  RESIDENCE - APT. HOUSE  ...       NaN
# ...            ...          ...                     ...  ...       ...
# 6366470     QUEENS     FRONT OF         RESIDENCE-HOUSE  ...       NaN
# 6367153   BROOKLYN       INSIDE  RESIDENCE - APT. HOUSE  ...       NaN
# 6377708   BROOKLYN          NaN                  STREET  ...       NaN
# 6424655   BROOKLYN       INSIDE  RESIDENCE - APT. HOUSE  ...       NaN
# 6515212   BROOKLYN     FRONT OF         PUBLIC BUILDING  ...       NaN
#
#         suspect_age    suspect_race suspect_sex  \
# 1558047         NaN         UNKNOWN         NaN
# 6045835         NaN             NaN         NaN
# 2328772     UNKNOWN           WHITE           M
# 2317128     UNKNOWN           WHITE           M
# 1849111     UNKNOWN           WHITE           M
# ...             ...             ...         ...
# 6366470         NaN             NaN         NaN
# 6367153       25-44         UNKNOWN           M
# 6377708         NaN           BLACK           M
# 6424655       18-24  BLACK HISPANIC           M
# 6515212         NaN             NaN         NaN
#
#                                       coordinates            patrol_borough  \
# 1558047             (40.694627922, -73.735330379)  PATROL BORO QUEENS SOUTH
# 6045835             (40.633091977, -73.963184051)   PATROL BORO BKLYN SOUTH
# 2328772  (40.716195914000025, -73.99749074599998)     PATROL BORO MAN SOUTH
# 2317128  (40.716195914000025, -73.99749074599998)     PATROL BORO MAN SOUTH
# 1849111  (40.716195914000025, -73.99749074599998)     PATROL BORO MAN SOUTH
# ...                                           ...                       ...
# 6366470             (40.729544666, -73.804199536)  PATROL BORO QUEENS SOUTH
# 6367153             (40.619442536, -73.999846551)   PATROL BORO BKLYN SOUTH
# 6377708              (40.669692375, -73.91074263)   PATROL BORO BKLYN NORTH
# 6424655             (40.706222013, -73.950974356)   PATROL BORO BKLYN NORTH
# 6515212             (40.685406712, -73.941423832)   PATROL BORO BKLYN NORTH
#
#         metro victim_age     victim_race victim_sex
# 1558047   NaN      25-44           BLACK          F
# 6045835   NaN      45-64           WHITE          M
# 2328772   NaN      45-64           WHITE          M
# 2317128   NaN      45-64           WHITE          M
# 1849111   NaN      45-64           WHITE          M
# ...       ...        ...             ...        ...
# 6366470   NaN      25-44           WHITE          F
# 6367153   NaN      25-44           WHITE          F
# 6377708   NaN      45-64  BLACK HISPANIC          M
# 6424655   NaN        <18  WHITE HISPANIC          F
# 6515212   NaN        NaN         UNKNOWN          D
#
# [6983207 rows x 21 columns]

# %%
data['date']

# %%
data[].to_csv('sample.csv')
