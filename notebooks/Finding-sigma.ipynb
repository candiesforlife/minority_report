# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy.ndimage import gaussian_filter

# %%
#Let's build a 3D array of axis: (t,x,y)
img3D = np.zeros((10,10,10))
img3D[5,5,5] = 1
img3D_conv = gaussian_filter(img3D, sigma=(2,2,2))
max_lum = img3D_conv.max()
for i in range(9):
    plt.imshow(img3D_conv[i+1,:,:], cmap='gray', vmin=0, vmax=max_lum)
    plt.show()

# %%
img3D = np.zeros((8,8,8))
img3D[5,5,5] = 1
img3D_conv = gaussian_filter(img3D, sigma=(2,2,2))
max_lum = img3D_conv.max()
for i in range(9):
    plt.imshow(img3D_conv[i+1,:,:], cmap='gray', vmin=0, vmax=max_lum)
    plt.show()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-14-5abc1ce952fc> in <module>
#       4 max_lum = img3D_conv.max()
#       5 for i in range(9):
# ----> 6     plt.imshow(img3D_conv[i+1,:,:], cmap='gray', vmin=0, vmax=max_lum)
#       7     plt.show()
#
# IndexError: index 8 is out of bounds for axis 0 with size 8

# %%
img3D = np.zeros((10,10,10))
img3D[5,5,5] = 1
img3D_conv = gaussian_filter(img3D, sigma=(1,1,0))
max_lum = img3D_conv.max()
for i in range(9):
    plt.imshow(img3D_conv[i+1,:,:], cmap='gray', vmin=0, vmax=max_lum)
    plt.show()

# %%
img3D = np.zeros((15,15,15))
img3D[7,7,7] = 1
img3D_conv = gaussian_filter(img3D, sigma=(1,1,1))
max_lum = img3D_conv.max()
for i in range(9):
    plt.imshow(img3D_conv[i+1,:,:], cmap='gray', vmin=0, vmax=max_lum)
    plt.show()

# %%
img3D = np.zeros((15,15,15))
img3D[7,7,7] = 1

img3D_conv = gaussian_filter(img3D, sigma=(2,1,1))
max_lum = img3D_conv.max()
for i in range(9):
    plt.imshow(img3D_conv[i+1,:,:], cmap='gray', vmin=0, vmax=max_lum)
    plt.show()

# %%
img3D = np.zeros((15,15,15))
img3D[7,7,7] = 1

img3D_conv = gaussian_filter(img3D, sigma=(1,1,1))
max_lum = img3D_conv.max()
for i in range(9):
    plt.imshow(img3D_conv[i+1,:,:], cmap='gray', vmin=0, vmax=max_lum)
    plt.show()

# %%
img3D = np.zeros((10,10,10))
img3D[5,5,5] = 1

img3D_conv = gaussian_filter(img3D, sigma=(1,2,2))
max_lum = img3D_conv.max()
for i in range(9):
    plt.imshow(img3D_conv[i+1,:,:], cmap='gray', vmin=0, vmax=max_lum)
    plt.show()

# %%
img3D = np.zeros((10,10,10))
img3D[5,5,5] = 1

img3D_conv = gaussian_filter(img3D, sigma=(1,1,2))
max_lum = img3D_conv.max()
for i in range(9):
    plt.imshow(img3D_conv[i+1,:,:], cmap='gray', vmin=0, vmax=max_lum)
    plt.show()

# %%
img3D = np.zeros((10,10,10))
img3D[5,5,5] = 1

img3D_conv = gaussian_filter(img3D, sigma=(1,2,1))
max_lum = img3D_conv.max()
for i in range(9):
    plt.imshow(img3D_conv[i+1,:,:], cmap='gray', vmin=0, vmax=max_lum)
    plt.show()

# %%
img3D = np.zeros((15,15,15))
img3D[7,7,7] = 1

img3D_conv = gaussian_filter(img3D, sigma=(1,2,2))
max_lum = img3D_conv.max()
for i in range(9):
    plt.imshow(img3D_conv[i+1,:,:], cmap='gray', vmin=0, vmax=max_lum)
    plt.show()

# %%
#increase sigma => large net over the pixels => more higher frequencies, image more blurry
#increase sigma => more variance allowed around the mean
#decrease of sigma => less variance allowed around mean.
#sigma is your Standard deviation for Gaussian kernel. 
#The standard deviations of the Gaussian filter are given for each axis as a sequence, or as a single number, in which case it is equal for all axes.

# %%
img3D = np.zeros((15,15,15))
img3D[7,7,7] = 1

img3D_conv = gaussian_filter(img3D, sigma=(1,1,1))
max_lum = img3D_conv.max()
for i in range(9):
    plt.imshow(img3D_conv[i+1,:,:], cmap='gray', vmin=0, vmax=max_lum)
    plt.show()

# %%
img3D = np.zeros((15,15,15))
img3D[6,7,7] = 1

img3D_conv = gaussian_filter(img3D, sigma=(2,2,2))
max_lum = img3D_conv.max()
for i in range(9):
    plt.imshow(img3D_conv[i+1,:,:], cmap='gray', vmin=0, vmax=max_lum)
    plt.show()

# %%
#sigma 1 => 2 x, 2y et 2temps (NB: on prendmoitie du cercle mais se rappeler que cela s'etend de chaque cote.)
#sigma 2 => 4x, 4y, et 4temps

# %%
# Calculer sigma pour le temps: 1 SEMAINE: 24h * 7jours = 168h temps.
    # valeurs de sigma represent the way we dilute the information of a crime.
    # sigma = 2 => 4heures 
 sigma = ? => 168heures. produit en croix nous donne un sigma de 84.
 
# calculer sigma pour longitude et latitude:

# %%
def getting_sigma_values(self, parameter_one_dimension):
        # time parameter will be in hour already
        #sigma 1 => 2 x, 2y et 2temps (NB: on prend moitie du cercle mais se rappeler que cela s'etend de chaque cote.)
        #sigma 2 => 4x, 4y, et 4temps

        return parameter_one_dimension / 2

def gaussian_filtering(self,img3D,raw_z,raw_x,raw_y):
        '''
          Returns img3D convoluted
        '''
        x = self.getting_sigma_values(raw_x)
        y = self.getting_sigma_values(raw_y)
        z = self.getting_sigma_values(raw_z)

        self.img3D_conv = gaussian_filter(img3D, sigma=(z,x,y))
        return self.img3D_conv
