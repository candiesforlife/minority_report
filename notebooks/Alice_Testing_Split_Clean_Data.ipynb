# %%
import pandas as pd
import pickle

# %%
with open('../raw_data/test_df.pickle', 'rb') as f:
            test_df = pickle.load(f)

# %%
with open('../raw_data/train_df.pickle', 'rb') as g:
    train_df = pickle.load(g)

# %%
test_df.head(3)
# Out:
#      precinct_number                    offense_type crime_completed  \
# 55                75  CRIMINAL MISCHIEF & RELATED OF       COMPLETED
# 203               75    ASSAULT 3 & RELATED OFFENSES       COMPLETED
# 268               75  CRIMINAL MISCHIEF & RELATED OF       COMPLETED
#
#     offense_level premise_desc                 premise      jurisdiction  \
# 55    MISDEMEANOR      REAR OF       FACTORY/WAREHOUSE  N.Y. POLICE DEPT
# 203   MISDEMEANOR     FRONT OF  RESIDENCE - APT. HOUSE  N.Y. POLICE DEPT
# 268   MISDEMEANOR     FRONT OF       CLOTHING/BOUTIQUE  N.Y. POLICE DEPT
#
#     park_name suspect_age    suspect_race  ...   latitude  longitude  \
# 55   NOT PARK     UNKNOWN           BLACK  ...  40.663657 -73.901087
# 203  NOT PARK       25-44  WHITE HISPANIC  ...  40.673450 -73.885434
# 268  NOT PARK     UNKNOWN         UNKNOWN  ...  40.681223 -73.880658
#
#            metro victim_age victim_race victim_sex               period  \
# ...

# %%
train_df.head(3)
# Out:
#      precinct_number                  offense_type crime_completed  \
# 73                75               DANGEROUS DRUGS       COMPLETED
# 99                75  ASSAULT 3 & RELATED OFFENSES       COMPLETED
# 251               75                 PETIT LARCENY       COMPLETED
#
#     offense_level premise_desc                 premise      jurisdiction  \
# 73    MISDEMEANOR      UNKNOWN                   OTHER  N.Y. POLICE DEPT
# 99    MISDEMEANOR       INSIDE  RESIDENCE - APT. HOUSE  N.Y. POLICE DEPT
# 251   MISDEMEANOR       INSIDE             CHAIN STORE  N.Y. POLICE DEPT
#
#     park_name suspect_age suspect_race  ...   latitude  longitude  \
# 73   NOT PARK     UNKNOWN      UNKNOWN  ...  40.666027 -73.896318
# 99   NOT PARK     UNKNOWN      UNKNOWN  ...  40.679690 -73.866463
# 251  NOT PARK     UNKNOWN      UNKNOWN  ...  40.651701 -73.868447
#
#            metro victim_age     victim_race victim_sex               period  \
# ...

# %%
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 149575 entries, 73 to 6983160
# Data columns (total 21 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   precinct_number  149575 non-null  int64
#  1   offense_type     149575 non-null  object
#  2   crime_completed  149575 non-null  object
#  3   offense_level    149575 non-null  object
#  4   premise_desc     149575 non-null  object
#  5   premise          149575 non-null  object
#  6   jurisdiction     149575 non-null  object
#  7   park_name        149575 non-null  object
#  8   suspect_age      149575 non-null  object
#  9   suspect_race     149575 non-null  object
#  10  suspect_sex      149575 non-null  object
#  11  latitude         149575 non-null  float64
#  12  longitude        149575 non-null  float64
#  13  metro            149575 non-null  object
#  14  victim_age       149575 non-null  object
#  15  victim_race      149575 non-null  object
# ...

# %%
test_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 56942 entries, 55 to 6983184
# Data columns (total 21 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   precinct_number  56942 non-null  int64
#  1   offense_type     56942 non-null  object
#  2   crime_completed  56942 non-null  object
#  3   offense_level    56942 non-null  object
#  4   premise_desc     56942 non-null  object
#  5   premise          56942 non-null  object
#  6   jurisdiction     56942 non-null  object
#  7   park_name        56942 non-null  object
#  8   suspect_age      56942 non-null  object
#  9   suspect_race     56942 non-null  object
#  10  suspect_sex      56942 non-null  object
#  11  latitude         56942 non-null  float64
#  12  longitude        56942 non-null  float64
#  13  metro            56942 non-null  object
#  14  victim_age       56942 non-null  object
#  15  victim_race      56942 non-null  object
# ...
